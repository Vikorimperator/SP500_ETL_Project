# %% [markdown]
# # Carga de modulos

# %%
import os
import pandas as pd

# %% [markdown]
# # Carga del dato crudo

# %%
# Cargar el archivo CSV
raw_all_stocks_path = '../data/raw/all_stocks_5yr.csv'
raw = pd.read_csv(raw_all_stocks_path)

# %% [markdown]
# # Analisis exploratorio del dato

# %%
# Revisar tipos de datos
print("Tipos de datos:")
print(raw.dtypes)
# Out:
# Tipos de datos:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
# Convertir la columna 'date' a formato de fecha
raw['date'] = pd.to_datetime(raw['date'], errors='coerce')

# Verificar si hubo algún valor inválido convertido a NaT (Not a Time)
valores_invalidos = raw['date'].isnull().sum()
if valores_invalidos > 0:
    print(f"Se encontraron {valores_invalidos} valores inválidos en la columna 'date'.")
else:
    print("Todos los valores de la columna 'date' son válidos.")
# Out:
# Todos los valores de la columna 'date' son válidos.

# %%
# Revisar si hay valores nulos
print("Valores nulos por columna:")
print(raw.isnull().sum())
# Out:
# Valores nulos por columna:
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# Name       0
# dtype: int64

# %%
# Revisar las filas con valores nulos
nulos = raw[raw.isnull().any(axis=1)]
print(nulos)
# Out:
#              date  open   high    low     close   volume  Name
# 82949  2017-07-26   NaN    NaN    NaN   69.0842        3   BHF
# 165734 2015-07-17   NaN  88.76  88.24   88.7200  2056819   DHR
# 165857 2016-01-12   NaN    NaN    NaN   88.5500        0   DHR
# 205076 2015-07-17   NaN  48.49  47.85   47.9200  1246786    ES
# 239832 2016-07-01   NaN    NaN    NaN   49.5400        0   FTV
# 434379 2015-07-17   NaN  47.31  46.83   46.9900  1229513     O
# 434502 2016-01-12   NaN    NaN    NaN   52.4300        0     O
# 478594 2015-06-09   NaN    NaN    NaN  526.0900    12135  REGN
# 558213 2016-04-07   NaN    NaN    NaN   41.5600        0    UA
# 581906 2015-05-12   NaN    NaN    NaN  124.0800   569747  VRTX
# 598236 2015-06-26   NaN    NaN    NaN   61.9000      100   WRK

# %%
# Aplicar Forward Fill para las columnas con valores nulos
df_clean = raw.ffill()

# Verificar que no haya valores nulos después del Forward Fill
print("Valores nulos después del Forward Fill:")
print(df_clean.isnull().sum())
# Out:
# Valores nulos después del Forward Fill:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
# Identificar duplicados
duplicados = df_clean.duplicated().sum()
print(f"Filas duplicadas: {duplicados}")
# Out:
# Filas duplicadas: 0

# %% [markdown]
# # Generar archivos de prueba

# %%
# Filtramos por valores únicos de la columna 'name'
unique_names = df_clean['Name'].unique()

print(f'Numero total de empresas unicas: {len(unique_names)}')
# Out:
# Numero total de empresas unicas: 505

# %%
# Definimos la fecha deseada
fecha = '08/02/2018'

# Creamos un diccionario con los valores que queremos que aparezcan en cada CSV
data = {
    'date': [fecha],
    'open': [50],
    'high': [50],
    'low': [50],
    'close': [50],
    'volume': [50]
}

# Recorremos los nombres únicos y creamos un archivo CSV para cada uno
for name in unique_names:
    # Añadimos el nombre específico al diccionario
    data['Name'] = [name]
    
    # Convertimos el diccionario en un DataFrame
    df_name = pd.DataFrame(data)
    
    # Guardamos el DataFrame en un archivo CSV con el nombre de la empresa
    filename = f"../data/raw/daily_stocks/{name}_data.csv"
    df_name.to_csv(filename, index=False)

    print(f"Archivo {filename} generado correctamente.")
# Out:
# Archivo ../data/raw/daily_stocks/AAL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AAPL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AAP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ABBV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ABC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ABT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ACN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ADBE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ADI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ADM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ADP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ADSK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ADS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AEE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AEP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AES_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AET_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AFL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AGN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AIG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AIV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AIZ_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AJG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AKAM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ALB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ALGN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ALK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ALLE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ALL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ALXN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AMAT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AMD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AME_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AMGN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AMG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AMP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AMT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AMZN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ANDV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ANSS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ANTM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AON_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AOS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/APA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/APC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/APD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/APH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/APTV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ARE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ARNC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ATVI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AVB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AVGO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AVY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AWK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AXP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AYI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/AZO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/A_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BAC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BAX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BBT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BBY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BDX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BEN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BF.B_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BHF_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BHGE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BIIB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BLK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BLL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BMY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BRK.B_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BSX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BWA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/BXP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CAG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CAH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CAT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CBG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CBOE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CBS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CCI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CCL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CDNS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CELG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CERN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CFG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CF_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CHD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CHK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CHRW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CHTR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CINF_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CLX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CMA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CMCSA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CME_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CMG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CMI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CMS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CNC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CNP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/COF_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/COG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/COL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/COO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/COP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/COST_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/COTY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CPB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CRM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CSCO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CSRA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CSX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CTAS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CTL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CTSH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CTXS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CVS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CVX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/CXO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/C_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DAL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DFS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DGX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DHI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DHR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DISCA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DISCK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DISH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DIS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DLR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DLTR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DOV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DPS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DRE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DRI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DTE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DUK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DVA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DVN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DWDP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/DXC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/D_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EBAY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ECL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ED_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EFX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EIX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EMN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EMR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EOG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EQIX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EQR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EQT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ESRX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ESS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ES_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ETFC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ETN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ETR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EVHC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EXC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EXPD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EXPE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/EXR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FAST_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FBHS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FCX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FDX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FFIV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FISV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FIS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FITB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FLIR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FLR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FLS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FMC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FOXA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FOX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FRT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FTI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/FTV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/F_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GGP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GILD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GIS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GLW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GOOGL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GOOG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GPC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GPN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GPS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GRMN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/GWW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HAL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HAS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HBAN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HBI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HCA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HCN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HCP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HES_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HIG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HII_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HLT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HOG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HOLX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HON_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HPE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HPQ_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HRB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HRL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HRS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HSIC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HST_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HSY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/HUM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IBM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ICE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IDXX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IFF_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ILMN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/INCY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/INFO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/INTC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/INTU_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IPG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IQV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IRM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ISRG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ITW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/IVZ_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/JBHT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/JCI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/JEC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/JNJ_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/JNPR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/JPM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/JWN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KEY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KHC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KIM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KLAC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KMB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KMI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KMX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KORS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KSS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/KSU_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/K_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LEG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LEN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LKQ_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LLL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LLY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LMT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LNC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LNT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LOW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LRCX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LUK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LUV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/LYB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/L_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MAA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MAC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MAR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MAS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MAT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MCD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MCHP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MCK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MCO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MDLZ_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MDT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MET_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MGM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MHK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MKC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MLM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MMC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MMM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MNST_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MON_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MOS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MPC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MRK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MRO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MSFT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MSI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MTB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MTD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MU_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/MYL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/M_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NAVI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NBL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NCLH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NDAQ_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NEE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NEM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NFLX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NFX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NKE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NLSN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NOC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NOV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NRG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NSC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NTAP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NTRS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NUE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NVDA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NWL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NWSA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/NWS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/OKE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/OMC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ORCL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ORLY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/OXY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/O_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PAYX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PBCT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PCAR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PCG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PCLN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PDCO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PEG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PEP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PFE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PFG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PGR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PHM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PKG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PKI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PLD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PNC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PNR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PNW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PPG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PPL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PRGO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PRU_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PSA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PSX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PVH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PWR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PXD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/PYPL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/QCOM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/QRVO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RCL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/REGN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/REG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RF_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RHI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RHT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RJF_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RMD_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ROK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ROP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ROST_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RRC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RSG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/RTN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SBAC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SBUX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SCG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SCHW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SEE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SHW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SIG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SJM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SLB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SLG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SNA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SNI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SNPS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SPGI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SPG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SRCL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SRE_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/STI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/STT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/STX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/STZ_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SWKS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SWK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SYF_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SYK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SYMC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/SYY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TAP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TDG_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TEL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TGT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TIF_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TJX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TMK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TMO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TPR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TRIP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TROW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TRV_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TSCO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TSN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TSS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TWX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TXN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/TXT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/T_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UAA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UAL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UDR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UHS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ULTA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UNH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UNM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UNP_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UPS_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/URI_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/USB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/UTX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VAR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VFC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VIAB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VLO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VMC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VNO_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VRSK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VRSN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VRTX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VTR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/VZ_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/V_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WAT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WBA_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WDC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WEC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WFC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WHR_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WLTW_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WMB_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WMT_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WRK_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WU_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WYNN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WYN_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/WY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/XEC_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/XEL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/XLNX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/XL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/XOM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/XRAY_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/XRX_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/XYL_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/YUM_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ZBH_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ZION_data.csv generado correctamente.
# Archivo ../data/raw/daily_stocks/ZTS_data.csv generado correctamente.
